# %%
from src.db.db_utils import get_sqlite_engine
import pandas as pd

engine = get_sqlite_engine()
query = "SELECT name FROM sqlite_master WHERE type='table';"
tables = pd.read_sql(query, engine)
print(tables)
